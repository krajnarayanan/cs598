# %% [markdown]
# Raj Narayanan
# Assignment 1
# Feed Forward network from scratch

# %% [markdown]
# The network has two input features, one hidden layed with four nodes and one output layer
# There are 8 + 4 weights in the sigma set, 2x4 input weight and 1x4 output weight for each node in the hidden layer
# we are using two feratures in the wine databse to test the network.
#
# I am planning to add back propagation to update weights to increase accuracy of predictions later

# %%
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn import datasets
import matplotlib.pyplot as plt
# %matplotlib inline
#test

# %%
# get wind qulaity data
wine_quality = pd.read_csv("https://raw.githubusercontent.com/shrikant-temburwar/Wine-Quality-Dataset/master/winequality-white.csv", sep=';')

# %%
wine_quality
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
# Drop all colums except residual sugar and alcohol
X = wine_quality.drop(['fixed acidity','volatile acidity','citric acid','chlorides',
                   'free sulfur dioxide','total sulfur dioxide',
                   'density','pH','sulphates',
                   'quality'], axis=1).values
y = wine_quality[['quality']].values

# %%
X[:10]
y
# Out:
# array([[6],
#        [6],
#        [6],
#        ...,
#        [6],
#        [7],
#        [6]])

# %%
# plot the data
x1 = X[:,0]
x2 = X[:,1]
plt.figure(figsize=(10,7))
plt.scatter(x1, x2, c= y, cmap=plt.cm.coolwarm)
y = y.reshape(y.shape[0],1)
y
# Out:
# array([[6],
#        [6],
#        [6],
#        ...,
#        [6],
#        [7],
#        [6]])

# %%
# generate random weights and bias
def generate_sigma(weights):
    weight_list = []
    bias_list = []
    for i in range(len(weights) - 1):
        w = np.random.randn(weights[i], weights[i+1])
        b = np.random.randn()
        weight_list.append(w)
        bias_list.append(b)
    return weight_list, bias_list

# %%
# sigmod function to appky logistic regression to the data
def sigmoid(x):
    return 1/(1+np.exp(-x))

# %%
# predicated value
def find_y(w, b, X):
    zh = np.dot(X,w[0]) + b[0]
    ah = sigmoid(zh)
    zo = np.dot(ah, w[1]) + b[1]
    ao = sigmoid(zo)
    return ao

# %%
def forward_only_network(X, y, lr, epochs):
    input_len = X.shape[1]
    output_len = y.shape[1]
    w,b = generate_sigma([input_len, 4, output_len])
    for i in range(epochs):
        ao = find_y(w, b, X)
        print(ao)
    return w, b, error_list

# %%
lr = 0.5
epochs = 2000
w, b, error_list = forward_only_network(X,y,lr,epochs)
# Out:
# [[0.38435788]
#  [0.30602982]
#  [0.36514689]
#  ...
#  [0.30554175]
#  [0.3051166 ]
#  [0.30493432]]
# [[0.38435788]
#  [0.30602982]
#  [0.36514689]
#  ...
#  [0.30554175]
#  [0.3051166 ]
#  [0.30493432]]
# [[0.38435788]
#  [0.30602982]
#  [0.36514689]
#  ...
#  [0.30554175]
#  [0.3051166 ]
#  [0.30493432]]
# [[0.38435788]
#  [0.30602982]
#  [0.36514689]
#  ...
#  [0.30554175]
#  [0.3051166 ]
#  [0.30493432]]
# [[0.38435788]
#  [0.30602982]
#  [0.36514689]
#  ...
#  [0.30554175]
#  [0.3051166 ]
#  [0.30493432]]
# [[0.38435788]
#  [0.30602982]
#  [0.36514689]
#  ...
#  [0.30554175]
#  [0.3051166 ]
#  [0.30493432]]
# [[0.38435788]
#  [0.30602982]
#  [0.36514689]
#  ...
#  [0.30554175]
#  [0.3051166 ]
#  [0.30493432]]
# [[0.38435788]
#  [0.30602982]
#  [0.36514689]
#  ...
#  [0.30554175]
#  [0.3051166 ]
#  [0.30493432]]
# [[0.38435788]
#  [0.30602982]
#  [0.36514689]
#  ...
#  [0.30554175]
#  [0.3051166 ]
#  [0.30493432]]
# [[0.38435788]
#  [0.30602982]
#  [0.36514689]
#  ...
# ...
